# %%
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append(os.path.abspath('..'))
# import lib_plot

from lib_fitting import lin_fit
from lib_equations import trapezoidal, Simpson, Gauss_quad
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # **2-Points Gauss Quadrature**

# %%
# Params
a = -1
b = 1
dx_ = 1e-6

func = np.exp

res = Gauss_quad(func, a, b, dx_)

# Results
print(f'a = {a}')
print(f'b = {b}\n')
true = func(b) - func(a)

print('true =', true)
print('I{a, b} =', res)
print('\ndiff =', abs(true - res))
# Out:
# a = -1
# b = 1
#
# true = 2.3504023872876028
# I{a, b} = 2.350402387287603
#
# diff = 4.440892098500626e-16
